# %%
# Scrapping from reclameaqui.com.br
import pandas as pd
import time
import random
import os
from selenium.webdriver.common.by import By
import undetected_chromedriver as uc
import setuptools._distutils


empresas_totoal = pd.read_csv('empresas_total.csv')
empresas = empresas_totoal['Nome'].tolist()


for empresa in empresas[:50]:

    # URL da pagina principal da empresa
    url_p = 'https://www.reclameaqui.com.br/empresa/' + empresa + '/'

    # URL da pagina de reclamações da empresa
    def url_r(page : int, type : str = 'EVALUATED') -> str:

        # https://www.reclameaqui.com.br/empresa/temu/lista-reclamacoes/?pagina=1&status=EVALUATED
        return 'https://www.reclameaqui.com.br/empresa/' + empresa + '/lista-reclamacoes/?pagina='+ str(page) +'&status=' + type



    # pegando metadados da empresa (nome, categoria, reputação, sobre)
    if not os.path.exists(f'metadados/metadados_{empresa}.csv'):
        try:

            driver = uc.Chrome()

            # acessando a pagina principal da empresa
            driver.get(url_p)

            time.sleep(random.randint(2,4))
                
            # ramo de atividade da empresa
            categoria = driver.find_element(By.ID, 'info_segmento_hero').text

            # reputação da empresa
            reputacao = driver.find_element(By.ID, 'tag_reputacao_hero').text

            # sobre a empresa
            sobre = driver.find_element(By.CSS_SELECTOR, 'ul.sc-1915fv4-2.idgfcC').text
            sobre = sobre.split("\n")[0] 

            metadata = {
                'nome': empresa,
                'categoria': categoria,         
                'reputacao': reputacao,         
                'sobre': sobre       
            }

            driver.quit()
            
            metadata_p = pd.DataFrame(metadata, index=[0])
            metadata_p.to_csv(f'metadados/metadados_{empresa}.csv', index=False)
            
        except: 
            driver.quit()
            os._exit(1)

    else:
    
        metadata = pd.read_csv(f'metadados/metadados_{empresa}.csv')
        metadata = metadata.to_dict(orient='records')[0]
    
    
    print(metadata)


   


    # pegando hyperlinks das reclamações avaliadas e/ou respondidas

    all_hyperlinks = []
    
    Numero_de_paginas = 50 # máximo

    # Se o CSV ainda não existe, inicia a coleta
    if not os.path.exists(f'hyperlinks/hyperlinks_{empresa}.csv'):
    
        for i in range(Numero_de_paginas):

            try:
                driver = uc.Chrome()
                
                driver.get(url_r(page=i + 1, type='EVALUATED'))
                
                time.sleep(random.randint(2, 4))
                
                
                # Captura os hyperlinks da página atual
                div_hyperlinks = driver.find_elements(By.CSS_SELECTOR, 'div.sc-1pe7b5t-0.eJgBOc')
                current_hyperlinks = [h.find_element(By.CSS_SELECTOR, 'a').get_attribute('href') for h in div_hyperlinks]
                
                if not current_hyperlinks:
                    print("Nenhum hyperlink encontrado")
                    driver.quit()
                    break

                print(f"Página {i+1} - hyperlinks: {current_hyperlinks}")
                all_hyperlinks += current_hyperlinks

                driver.quit()

                
            except Exception as e:
                driver.quit()
                os._exit(1)
              


        df = pd.DataFrame(all_hyperlinks, columns=["Hyperlinks"])
        df.to_csv(f'hyperlinks/hyperlinks_{empresa}.csv', index=False)
        all_hyperlinks = df["Hyperlinks"].tolist()
        
    else:
        
        # Se o CSV já existe, apenas o lê
        df = pd.read_csv(f'hyperlinks/hyperlinks_{empresa}.csv')
        all_hyperlinks = df["Hyperlinks"].tolist()

    print(all_hyperlinks)
    

    
    # pegando dados das reclamações respondidas

    if not os.path.exists(f'reclamacoes/reclamacoes_{empresa}.csv'):

        driver = uc.Chrome()
    
        reclamacoes = []
        #for link in all_hyperlinks:
        for link in all_hyperlinks:
            
            links_coletados = set()
            
            if link in links_coletados:
                continue
            
            links_coletados.add(link)
            
            try:
                driver.get(link)

                time.sleep(random.randint(4, 5))

                titulo = driver.find_element(By.CSS_SELECTOR, '[data-testid="complaint-title"]').text
                lugar = driver.find_element(By.CSS_SELECTOR, '[data-testid="complaint-location"]').text
                data = driver.find_element(By.CSS_SELECTOR, '[data-testid="complaint-creation-date"]').text
                reclamacao_id = driver.find_element(By.CSS_SELECTOR, '[data-testid="complaint-id"]').text
                
                reclamacao_id = (reclamacao_id.split('ID: ')[1])

                parsed_data = time.strptime(data, '%d/%m/%Y às %H:%M')

                reclamacao_base = driver.find_element(By.CSS_SELECTOR, '.sc-lzlu7c-17.fRVYjv').text
                interacoes = driver.find_elements(By.CSS_SELECTOR, '[data-testid="complaint-interaction"]')

                interacoes_text = [i.text for i in interacoes]

                again = driver.find_element(By.CSS_SELECTOR, '.sc-uh4o7z-0.bprQlw:nth-child(2) > div').text
                rating = driver.find_element(By.CSS_SELECTOR, '.sc-uh4o7z-0.bprQlw:nth-child(3) > div').text
                status = driver.find_element(By.CSS_SELECTOR, '[data-testid="complaint-status"]').text

                rating = int(rating.split()[0])
                again = again == 'Sim'

                reclamacao = {
                    'id': reclamacao_id,
                    'titulo': titulo,
                    'lugar': lugar,
                    'data': parsed_data,
                    'reclamacao_base': reclamacao_base,
                    'interacoes': interacoes_text,
                    'rating': rating,
                    'again': again,
                    'status': status
                }

                reclamacoes.append(reclamacao)
                
                print(reclamacao)
                
            except:
                
                driver.quit()
                os._exit(1)


        driver.quit()
 
            
        # transformando em csv as reclamações
        df = pd.DataFrame(reclamacoes)
        df.to_csv(f'reclamacoes/reclamacoes_{empresa}.csv', index=False)
            

    else: 
        
        df = pd.read_csv(f'reclamacoes/reclamacoes_{empresa}.csv')
        reclamacoes = df.to_dict(orient='records')
                
    
    print(reclamacoes)
# Out:
# {'nome': 'malibu', 'categoria': 'Bancos e Financeiras', 'reputacao': 'Ótimo', 'sobre': 'A Texapays oferece soluções seguras, rápidas e eficientes para integrar pagamentos em sua empresa. Com uma plataforma simples e suporte dedicado.'}
# Página 1 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/nao-recebi-o-codigo-de-rastreio_LQ9z0FNOXpllKot1/', 'https://www.reclameaqui.com.br/malibu/acai-nacional_vM8qFo5KjUf1lkIe/', 'https://www.reclameaqui.com.br/malibu/loja_5A4_yx0sEeS8V4JB/', 'https://www.reclameaqui.com.br/malibu/compra-nao-foi-entregue_Qtx0uAUN23YCAbsg/', 'https://www.reclameaqui.com.br/malibu/reclamacao_ZLMefJC6s5W-VFYK/', 'https://www.reclameaqui.com.br/malibu/compra-pix-donaflorr_pqiQzjzC3-4b_WiU/', 'https://www.reclameaqui.com.br/malibu/venda-enganosa_dV4KDM10Eaqewo3b/', 'https://www.reclameaqui.com.br/malibu/nao-recebimento-de-produto_8ih27wRblIyrQSZ6/', 'https://www.reclameaqui.com.br/malibu/reembolso_jqEdbWIuO8cy-E4c/', 'https://www.reclameaqui.com.br/malibu/compra-feita-e-nao-entregou_uZmwQ3_08f-mrE_t/']
# Página 2 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/descaso_baHj2PdWLwaQ3ztY/', 'https://www.reclameaqui.com.br/malibu/compra-no-loja_NQXf6dd77Vvrwj9E/', 'https://www.reclameaqui.com.br/malibu/cair-no-paguei-nao-resebi-produto_RFS9ZCWjRBKkW2pA/', 'https://www.reclameaqui.com.br/malibu/reclamacao_Qq_8pXr2G_KFpNuE/', 'https://www.reclameaqui.com.br/malibu/reclamacao_Wc9nTB2oeGVl5VsO/', 'https://www.reclameaqui.com.br/malibu/fiz-pix-e-nao-recebi-ema-confirmando-a-compra_AbtOy0nFG02JYBH0/', 'https://www.reclameaqui.com.br/malibu/quero-meu-dinheiro-de-volta_k6_yH0sGbtGm4ZW5/', 'https://www.reclameaqui.com.br/malibu/texas-pay_f-wxbjzMkVEXJ9Jd/', 'https://www.reclameaqui.com.br/malibu/nao-recebi-o-produto_TS89dYi-fTU36fcy/', 'https://www.reclameaqui.com.br/malibu/texaspay-nao-recebi-o-produto_FjzkQGhaDLgkpCON/']
# Página 3 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/devolucao-do-pix_4SEg94OKNlKNfoFt/', 'https://www.reclameaqui.com.br/malibu/fiz-compra-atraves-de-pix-e-nao-recebi-a-encomenda_cNNMIBeD9EMNC-TS/', 'https://www.reclameaqui.com.br/malibu/pix-realized_JZmihVNK-1uX6yPy/', 'https://www.reclameaqui.com.br/malibu/reembolso-de-pagamento-de-cnpj-inexistente_GbrQIsuRljbSr_GB/', 'https://www.reclameaqui.com.br/malibu/venda-nao-concluida_bB87kW7rGhDCojmA/', 'https://www.reclameaqui.com.br/malibu/compra-online_M5b4olSUfg8Lp1Bz/', 'https://www.reclameaqui.com.br/malibu/compra-online_h9rmzuTTAt9K2i7b/', 'https://www.reclameaqui.com.br/malibu/videnc-loja-fake_xlaMt3voisNUKS95/', 'https://www.reclameaqui.com.br/malibu/levei-pela_zOP5xUPMiJI7Jjqm/', 'https://www.reclameaqui.com.br/malibu/nao-recebi-o-produto-comprado_XMoLct0-oKGXbrjh/']
# Página 4 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/comprei-e-nao-recebi-e-tambem-nao-faz-reembolso_qZmXslQ7a6ZjiuVG/', 'https://www.reclameaqui.com.br/malibu/texas-payloja-feminnelle-shop_-FVBD2xHL4sfVSyG/', 'https://www.reclameaqui.com.br/malibu/reclamacao_H8vF7ETcrxMBGWfj/', 'https://www.reclameaqui.com.br/malibu/fiz-um-pix-da-compra-e-nao-recebi-o-produto_YsxSU5wsJVxkmDAo/', 'https://www.reclameaqui.com.br/malibu/loja_xmZ4WFeumP_iqDKq/', 'https://www.reclameaqui.com.br/malibu/nao-comprem-texaspay-voluti-e-loja-feminnelle_-Hgr72ANyMkUHthl/', 'https://www.reclameaqui.com.br/malibu/pix-efetuado-e-cade-meu-produto-quero-meu-dinheiro-de-volta_OHeMtGcySBZdEBl3/', 'https://www.reclameaqui.com.br/malibu/imposto-pago_KYKkf1B-KKPFJ0sl/', 'https://www.reclameaqui.com.br/malibu/quero-reembolso_NxYLhqAOUUrGJc1s/', 'https://www.reclameaqui.com.br/malibu/compra-nao-entregue_Tld2LMDZVwQTpjAC/']
# Página 5 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/compra-loja-feminelle_gZFsYDJbRBa_PsbG/', 'https://www.reclameaqui.com.br/malibu/voluti_kb89IGjNp5XYQGcs/', 'https://www.reclameaqui.com.br/malibu/feminnelletexaspay_L6mxirUEaqwcmjdu/', 'https://www.reclameaqui.com.br/malibu/compra-na-loja-feminnelle-com-pagamento-via-pix-para-texaspay_IJ6Co4hBoNp7GWES/', 'https://www.reclameaqui.com.br/malibu/reclamacao_qtEcEtBUifQSDj4X/', 'https://www.reclameaqui.com.br/malibu/loja-videnc-tecnologia-e-pagamentos-txas-ltda-e_U2h8qp6FbLFze6Gd/', 'https://www.reclameaqui.com.br/malibu/propaganda-enganosa_rwxMIA0Nllob04hA/', 'https://www.reclameaqui.com.br/malibu/texas-pay-e-voluti_K_AZCK_vYeIPmft4/', 'https://www.reclameaqui.com.br/malibu/compra-efetuada-porem-nao-recebida_18fnIwXNTCbilzEQ/', 'https://www.reclameaqui.com.br/malibu/reclamacao-sobre-compra-nao-entregue-e-falta-de-suporte_HRS75oGAv34B6GCg/']
# Página 6 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/comprei-na-feminnelle-e-o-pix-foi-para-essa-empresa_mgBEDadYGDOtrh1N/', 'https://www.reclameaqui.com.br/malibu/reclamacao_J34zx9Bm7qbYiBmg/', 'https://www.reclameaqui.com.br/malibu/loja-feminnelletexas-pay_pjBVzgWJoZ6gcGN9/', 'https://www.reclameaqui.com.br/malibu/loja-feminnele-e-uma-loja-fake-devolucao-do-pagamento_jWAVvM5kagWbswqq/', 'https://www.reclameaqui.com.br/malibu/comprei-produto-e-nao-recebi_KT7skJLszFwfB28t/', 'https://www.reclameaqui.com.br/malibu/reembolso_yiFaLv03-_mpfrMv/', 'https://www.reclameaqui.com.br/malibu/reclamacao_xfyXVEQxzN_Ytj96/', 'https://www.reclameaqui.com.br/malibu/do-vestido-feminalle_LgjMdJH7SRuy5Hw9/', 'https://www.reclameaqui.com.br/malibu/loja-feminnelle-tecnologia-e-pagamentos-txas-ltda_vfo1WzFhduDoiDLL/', 'https://www.reclameaqui.com.br/malibu/loja-videnc-voluti-pgament_Nnw9nEmZzy1w7ZIu/']
# Página 7 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/loja-feminnelle_NJkj8BTAzPo3-4Xu/', 'https://www.reclameaqui.com.br/malibu/feminneli-texaspay-voluti-tecnologia-e-pagamentos_tLnyyo7U7ipYOzPr/', 'https://www.reclameaqui.com.br/malibu/loja-feminnelle-e-fake_W4Ayr2QtUqDr4DI3/', 'https://www.reclameaqui.com.br/malibu/loja-de-roupas-online_PLZ6sZw5qje5wojH/', 'https://www.reclameaqui.com.br/malibu/compra-enganosa-loja-videnci_3eYaxUTX14impz1v/', 'https://www.reclameaqui.com.br/malibu/compra-nao-chegou_-4DzrGGk4iUcLrK2/', 'https://www.reclameaqui.com.br/malibu/loja-videnc-e_uwGuzdkbAR8Len5O/', 'https://www.reclameaqui.com.br/malibu/propaganda-enganosa-videnc_j9woLKSArKj17s75/', 'https://www.reclameaqui.com.br/malibu/comprei-uma-roupa-na-videnc-e-nao-chegou_mQ6uvYxtbjQaaQMd/', 'https://www.reclameaqui.com.br/malibu/loja-feminalle_W6fJgijB83YWYL36/']
# Página 8 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/compra-site-falso_XecZL8Icy_bQMV0d/', 'https://www.reclameaqui.com.br/malibu/fiz-uma-compra-online-na-loja-feminnelle_nGaOzg8DnibaokLL/', 'https://www.reclameaqui.com.br/malibu/loja-videnc-e-uma_LC4X5oJ6WRNtV62k/', 'https://www.reclameaqui.com.br/malibu/loja-feminnelle_GBK4Z4QYi_Xchjjc/', 'https://www.reclameaqui.com.br/malibu/loja-feminnelle_8mk_ERy-Vq5VjjGb/', 'https://www.reclameaqui.com.br/malibu/a-loja-videnc-e_-SZ1mOExJw11riuT/', 'https://www.reclameaqui.com.br/malibu/comprei-um-vestido-na-feminnelle__LVsKE-RI8AyF1T7/', 'https://www.reclameaqui.com.br/malibu/comprei-e-loja-nao-existe-quem-recebeu-foi-essa-texaspay_4_3kW9xSPFxDrARK/', 'https://www.reclameaqui.com.br/malibu/comprei-paguei-e-nao-recebi_5jZh-Lwm4RhDx6iE/', 'https://www.reclameaqui.com.br/malibu/quero-meu-dinheiro-de-volta_LZgztU0k8LnzTWMw/']
# Página 9 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/da-lojas-feminnelle_NRI3KtvaKqWDuWgZ/', 'https://www.reclameaqui.com.br/malibu/fiz-pix-para-essa-empresa-com-nome-de-texaspay_7XTiJKnIfcsOIGmp/', 'https://www.reclameaqui.com.br/malibu/loja-feminnelle-x-texaspay-tecnologia-e-pagamentos_PmdoUqZC9KRwPK1M/', 'https://www.reclameaqui.com.br/malibu/fui-enganado_FQGmE7taWpXuvhwc/', 'https://www.reclameaqui.com.br/malibu/creme-nunca-foi-entregue_EttHkOh-lxW228ie/', 'https://www.reclameaqui.com.br/malibu/mercadoria-nao-recebida_rF6MQUn9caupGpeU/', 'https://www.reclameaqui.com.br/malibu/lojas-malibu_IcW2wIByH2HLG2mt/', 'https://www.reclameaqui.com.br/malibu/comprei-uma-tenda-e-nao-recebi_lPnAydhQ6Ur5h4E0/', 'https://www.reclameaqui.com.br/malibu/nao-entregou-meu-pedido_ncIew2Lqqd5MHJm0/', 'https://www.reclameaqui.com.br/malibu/pq-nao-consigo-rastrear-meu-pedido_bz7kywSf1kk8SrR2/']
# Página 10 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/compra-de-um-ar-condicionado-portatil_RUOjOBDyhUzxYES2/', 'https://www.reclameaqui.com.br/malibu/comprei-e-nao-recebi-e-nao-vizualizar-as-mensagens-que-envio_Btdrg5CeRMnSHYAO/', 'https://www.reclameaqui.com.br/malibu/produto-nao-recebido_n2at1H5k-vIO8hOD/', 'https://www.reclameaqui.com.br/malibu/fiz-uma-compra-que-nunca-chegou_l9DgAGaqlXx7yOpv/', 'https://www.reclameaqui.com.br/malibu/atraso-ou_hXlOopmaJcNYQizI/', 'https://www.reclameaqui.com.br/malibu/paguei-e-o-pedido-nao-chegou_1ztoyIZURtfwarsU/', 'https://www.reclameaqui.com.br/malibu/na-blackfriday_FmnoK13TO5f8i8iD/', 'https://www.reclameaqui.com.br/malibu/o-produto-nao-foi-entregue-e-a-loja-nao-deu-suporte_k9Bw_CqEkJSFRzSE/', 'https://www.reclameaqui.com.br/malibu/nao-recebi-minha-compra_WM8X2QeUSXsOfNyI/', 'https://www.reclameaqui.com.br/malibu/produto-nao-processado_u2sbxFSEXz-0VGFp/']
# Página 11 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/produtos-nao-entregue_2sasLk_YTe8ScfTI/', 'https://www.reclameaqui.com.br/malibu/nao-consigo-me-comunicar-com-a-empresa_xARBRvmptgF19_p5/', 'https://www.reclameaqui.com.br/malibu/produto-nao-recebido-nao-consigo-contato_z9DapFXeFveZ0ahd/', 'https://www.reclameaqui.com.br/malibu/comprei-e-nao-recebi_s5iZ43vHNd68-uTl/', 'https://www.reclameaqui.com.br/malibu/comprei-e-nao-recebi-e-tambem-nao-respondem_qL3JLfTVBoABCJ2i/', 'https://www.reclameaqui.com.br/malibu/venda-enganosa_BBhc2PaEsyUUiAWt/', 'https://www.reclameaqui.com.br/malibu/nao-recebi-meu-objeto_xcEeGef66TCXhRL2/', 'https://www.reclameaqui.com.br/malibu/nao-tive-retorno-da-empresa_Sm2vBoiGPIS05jp-/', 'https://www.reclameaqui.com.br/malibu/suporte-lamentavel_y3zngQUBuEqTu_f4/', 'https://www.reclameaqui.com.br/malibu/suporte-lamentavel_IqIiXuTMaEvCTtpN/']
# Página 12 - hyperlinks: ['https://www.reclameaqui.com.br/malibu/comprei-par-de-meia-calca-peluciada-pelo-link-do-instagram-mas-recebi-meias-calcas-comuns_Wiz_VTDXGeRRm4O9/', 'https://www.reclameaqui.com.br/malibu/produto-nao-entregue_dtyD267hHZWmTL7L/']
# Nenhum hyperlink encontrado
# ['https://www.reclameaqui.com.br/malibu/nao-recebi-o-codigo-de-rastreio_LQ9z0FNOXpllKot1/', 'https://www.reclameaqui.com.br/malibu/acai-nacional_vM8qFo5KjUf1lkIe/', 'https://www.reclameaqui.com.br/malibu/loja_5A4_yx0sEeS8V4JB/', 'https://www.reclameaqui.com.br/malibu/compra-nao-foi-entregue_Qtx0uAUN23YCAbsg/', 'https://www.reclameaqui.com.br/malibu/reclamacao_ZLMefJC6s5W-VFYK/', 'https://www.reclameaqui.com.br/malibu/compra-pix-donaflorr_pqiQzjzC3-4b_WiU/', 'https://www.reclameaqui.com.br/malibu/venda-enganosa_dV4KDM10Eaqewo3b/', 'https://www.reclameaqui.com.br/malibu/nao-recebimento-de-produto_8ih27wRblIyrQSZ6/', 'https://www.reclameaqui.com.br/malibu/reembolso_jqEdbWIuO8cy-E4c/', 'https://www.reclameaqui.com.br/malibu/compra-feita-e-nao-entregou_uZmwQ3_08f-mrE_t/', 'https://www.reclameaqui.com.br/malibu/descaso_baHj2PdWLwaQ3ztY/', 'https://www.reclameaqui.com.br/malibu/compra-no-loja_NQXf6dd77Vvrwj9E/', 'https://www.reclameaqui.com.br/malibu/cair-no-paguei-nao-resebi-produto_RFS9ZCWjRBKkW2pA/', 'https://www.reclameaqui.com.br/malibu/reclamacao_Qq_8pXr2G_KFpNuE/', 'https://www.reclameaqui.com.br/malibu/reclamacao_Wc9nTB2oeGVl5VsO/', 'https://www.reclameaqui.com.br/malibu/fiz-pix-e-nao-recebi-ema-confirmando-a-compra_AbtOy0nFG02JYBH0/', 'https://www.reclameaqui.com.br/malibu/quero-meu-dinheiro-de-volta_k6_yH0sGbtGm4ZW5/', 'https://www.reclameaqui.com.br/malibu/texas-pay_f-wxbjzMkVEXJ9Jd/', 'https://www.reclameaqui.com.br/malibu/nao-recebi-o-produto_TS89dYi-fTU36fcy/', 'https://www.reclameaqui.com.br/malibu/texaspay-nao-recebi-o-produto_FjzkQGhaDLgkpCON/', 'https://www.reclameaqui.com.br/malibu/devolucao-do-pix_4SEg94OKNlKNfoFt/', 'https://www.reclameaqui.com.br/malibu/fiz-compra-atraves-de-pix-e-nao-recebi-a-encomenda_cNNMIBeD9EMNC-TS/', 'https://www.reclameaqui.com.br/malibu/pix-realized_JZmihVNK-1uX6yPy/', 'https://www.reclameaqui.com.br/malibu/reembolso-de-pagamento-de-cnpj-inexistente_GbrQIsuRljbSr_GB/', 'https://www.reclameaqui.com.br/malibu/venda-nao-concluida_bB87kW7rGhDCojmA/', 'https://www.reclameaqui.com.br/malibu/compra-online_M5b4olSUfg8Lp1Bz/', 'https://www.reclameaqui.com.br/malibu/compra-online_h9rmzuTTAt9K2i7b/', 'https://www.reclameaqui.com.br/malibu/videnc-loja-fake_xlaMt3voisNUKS95/', 'https://www.reclameaqui.com.br/malibu/levei-pela_zOP5xUPMiJI7Jjqm/', 'https://www.reclameaqui.com.br/malibu/nao-recebi-o-produto-comprado_XMoLct0-oKGXbrjh/', 'https://www.reclameaqui.com.br/malibu/comprei-e-nao-recebi-e-tambem-nao-faz-reembolso_qZmXslQ7a6ZjiuVG/', 'https://www.reclameaqui.com.br/malibu/texas-payloja-feminnelle-shop_-FVBD2xHL4sfVSyG/', 'https://www.reclameaqui.com.br/malibu/reclamacao_H8vF7ETcrxMBGWfj/', 'https://www.reclameaqui.com.br/malibu/fiz-um-pix-da-compra-e-nao-recebi-o-produto_YsxSU5wsJVxkmDAo/', 'https://www.reclameaqui.com.br/malibu/loja_xmZ4WFeumP_iqDKq/', 'https://www.reclameaqui.com.br/malibu/nao-comprem-texaspay-voluti-e-loja-feminnelle_-Hgr72ANyMkUHthl/', 'https://www.reclameaqui.com.br/malibu/pix-efetuado-e-cade-meu-produto-quero-meu-dinheiro-de-volta_OHeMtGcySBZdEBl3/', 'https://www.reclameaqui.com.br/malibu/imposto-pago_KYKkf1B-KKPFJ0sl/', 'https://www.reclameaqui.com.br/malibu/quero-reembolso_NxYLhqAOUUrGJc1s/', 'https://www.reclameaqui.com.br/malibu/compra-nao-entregue_Tld2LMDZVwQTpjAC/', 'https://www.reclameaqui.com.br/malibu/compra-loja-feminelle_gZFsYDJbRBa_PsbG/', 'https://www.reclameaqui.com.br/malibu/voluti_kb89IGjNp5XYQGcs/', 'https://www.reclameaqui.com.br/malibu/feminnelletexaspay_L6mxirUEaqwcmjdu/', 'https://www.reclameaqui.com.br/malibu/compra-na-loja-feminnelle-com-pagamento-via-pix-para-texaspay_IJ6Co4hBoNp7GWES/', 'https://www.reclameaqui.com.br/malibu/reclamacao_qtEcEtBUifQSDj4X/', 'https://www.reclameaqui.com.br/malibu/loja-videnc-tecnologia-e-pagamentos-txas-ltda-e_U2h8qp6FbLFze6Gd/', 'https://www.reclameaqui.com.br/malibu/propaganda-enganosa_rwxMIA0Nllob04hA/', 'https://www.reclameaqui.com.br/malibu/texas-pay-e-voluti_K_AZCK_vYeIPmft4/', 'https://www.reclameaqui.com.br/mal ...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
